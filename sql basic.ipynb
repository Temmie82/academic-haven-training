# %% [markdown]
# # SQL Final Exam: The Bookstore Challenge
#
# ### 1. Setup
# Run this to reset your database with fresh data for the exam.

# %%
# %load_ext sql
# %sql sqlite://

# %%sql
CREATE TABLE authors (a_id INTEGER PRIMARY KEY, name TEXT);
CREATE TABLE books (b_id INTEGER PRIMARY KEY, a_id INTEGER, title TEXT, price REAL, stock INTEGER);

INSERT INTO authors VALUES (1, 'J.K. Rowling'), (2, 'George Orwell'), (3, 'Aldous Huxley'), (4, 'New Author');
INSERT INTO books VALUES (1, 1, 'Harry Potter', 25.00, 10), (2, 2, '1984', 15.00, 5), (3, 2, 'Animal Farm', 12.00, 0), (4, NULL, 'Mystery Book', 10.00, 2);

# %% [markdown]
# ### Challenge 1: The Inventory Report
# Write a query that shows the **Author Name** and the **Book Title** for all books currently in stock (stock > 0).

# %%
-- Your Code Here

# %% [markdown]
# ### Challenge 2: The 'Lost' Authors
# Use a `LEFT JOIN` to find authors who do **not** have any books listed in our `books` table.

# %%
-- Your Code Here

# %% [markdown]
# ### Challenge 3: Financial Summary
# Calculate the **total value** of our entire inventory (Price * Stock) for all books combined.

# %%
-- Your Code Here

# %% [markdown]
# ---
# ## 🛑 Answer Key (Don't peek until you try!)
#
# **Q1:** `SELECT authors.name, books.title FROM books JOIN authors ON books.a_id = authors.a_id WHERE stock > 0;`
# **Q2:** `SELECT name FROM authors LEFT JOIN books ON authors.a_id = books.a_id WHERE books.title IS NULL;`
# **Q3:** `SELECT SUM(price * stock) AS total_inventory_value FROM books;`
